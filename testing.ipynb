# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\user\OneDrive - GYC\Desktop\ForwardCollege\Week3\EDA_dataset\ecommerce_customers.csv') 
print(df.head())
# Out:
#   customer_id          signup_date        age  gender region membership_level  \
# 0  CUST_00630  2020-01-20 22:25:20  42.195129  Female  South         Platinum
# 1  CUST_00789  2024-11-08 17:31:47  62.604921  Female  South           Silver
# 2  CUST_00685  2022-07-29 09:44:48  34.641314  Female   East           Bronze
# 3  CUST_00517  2022-12-12 07:21:44  23.369605    Male   West           Bronze
# 4  CUST_00530  2023-12-31 22:07:40        NaN  Female  North           Bronze
#
#    total_purchases  total_spend  avg_order_value  days_since_last_purchase  \
# 0                6       438.67            73.11                       209
# 1               10       628.39            62.84                        37
# 2               11       994.05            90.37                        75
# 3                5       468.03            93.61                        48
# 4               17       866.75            50.99                        59
#
#    satisfaction_score  referred_friends
# ...
